# %%
import json
import numpy as np
import neural_network as nn
import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
with open('drug_smiles_tfidf_vectors.json', 'r') as file:
    data = json.load(file)

# %%
#data[2]['tfidf_vector']
train_data = [data[i]['tfidf_vector'] for i in range(1, len(data))] #drug tfidf representations as dummy data

# %%
batch_size = 16
shuffle = True

X_train_tensor = torch.FloatTensor(train_data)
Y_train_tensor = torch.FloatTensor([np.random.rand() for i in train_data]) # random true values
train_loader = DataLoader(TensorDataset(X_train_tensor, Y_train_tensor), batch_size=batch_size, shuffle=shuffle)

# %%
# Create model
model = nn.ModularFCNN(
    input_size=2048,           # Number of input features
    hidden_layers=[512, 256, 128, 64],  # Hidden layer sizes
    dropout_rate=0.3,          
    activation='relu',         
    batch_norm=True            
)

# %%
# Create trainer
trainer = nn.NeuralNetworkTrainer(
    model=model,
    optimizer_name='adam',
    loss_fn_name='mse',
    learning_rate=0.001
)

# %%
# Train
trainer.fit(
    train_loader=train_loader,
    epochs=1000,
    verbose=True
)
# Out:
# Epoch 10/1000 - Train Loss: 0.1080
# Epoch 20/1000 - Train Loss: 0.0965
# Epoch 30/1000 - Train Loss: 0.0913
# Epoch 40/1000 - Train Loss: 0.0885
# Epoch 50/1000 - Train Loss: 0.0873
# Epoch 60/1000 - Train Loss: 0.0829
# Epoch 70/1000 - Train Loss: 0.0843
# Epoch 80/1000 - Train Loss: 0.0833
# Epoch 90/1000 - Train Loss: 0.0818
# Epoch 100/1000 - Train Loss: 0.0818
# Epoch 110/1000 - Train Loss: 0.0834
# Epoch 120/1000 - Train Loss: 0.0825
# Epoch 130/1000 - Train Loss: 0.0837
# Epoch 140/1000 - Train Loss: 0.0819
# Epoch 150/1000 - Train Loss: 0.0816
# Epoch 160/1000 - Train Loss: 0.0809
# Epoch 170/1000 - Train Loss: 0.0815
# Epoch 180/1000 - Train Loss: 0.0836
# Epoch 190/1000 - Train Loss: 0.0811
# Epoch 200/1000 - Train Loss: 0.0827
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 2
#       1 # Train
# ----> 2 trainer.fit(
#       3     train_loader=train_loader,
#       4     epochs=1000,
#       5     verbose=True
#       6 )
#
# File ~\Downloads\Drug-Response-Prediction\neural_network.py:308, in NeuralNetworkTrainer.fit(self, train_loader, val_loader, epochs, metrics, verbose, early_stopping_patience)
#     304 patience_counter = 0
#     306 for epoch in range(epochs):
#     307     # Train
# --> 308     train_loss, train_metrics = self.train_epoch(train_loader, metrics)
#     309     self.train_losses.append(train_loss)
#     310     self.train_metrics.append(train_metrics)
#
# File ~\Downloads\Drug-Response-Prediction\neural_network.py:218, in NeuralNetworkTrainer.train_epoch(self, train_loader, metrics)
#     216 # Backward pass
#     217 loss.backward()
# --> 218 self.optimizer.step()
#     220 total_loss += loss.item()
#     221 num_batches += 1
#
# File ~\anaconda3\lib\site-packages\torch\optim\optimizer.py:516, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     511         else:
#     512             raise RuntimeError(
#     513                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     514             )
# --> 516 out = func(*args, **kwargs)
#     517 self._optimizer_step_code()
#     519 # call optimizer step post hooks
#
# File ~\anaconda3\lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~\anaconda3\lib\site-packages\torch\optim\adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)
#     244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~\anaconda3\lib\site-packages\torch\optim\optimizer.py:149, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     147     return disabled_func(*args, **kwargs)
#     148 else:
# --> 149     return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\torch\optim\adam.py:949, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     946 else:
#     947     func = _single_tensor_adam
# --> 949 func(
#     950     params,
#     951     grads,
#     952     exp_avgs,
#     953     exp_avg_sqs,
#     954     max_exp_avg_sqs,
#     955     state_steps,
#     956     amsgrad=amsgrad,
#     957     has_complex=has_complex,
#     958     beta1=beta1,
#     959     beta2=beta2,
#     960     lr=lr,
#     961     weight_decay=weight_decay,
#     962     eps=eps,
#     963     maximize=maximize,
#     964     capturable=capturable,
#     965     differentiable=differentiable,
#     966     grad_scale=grad_scale,
#     967     found_inf=found_inf,
#     968     decoupled_weight_decay=decoupled_weight_decay,
#     969 )
#
# File ~\anaconda3\lib\site-packages\torch\optim\adam.py:464, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     462         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     463 else:
# --> 464     exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     466 if capturable or differentiable:
#     467     step = step_t
#
# KeyboardInterrupt:

# %%
# Predict
predictions = trainer.predict(X_train_tensor)

# %%
predictions
# Out:
# array([[0.49191466],
#        [0.48773098],
#        [0.4878771 ],
#        [0.46975085],
#        [0.4816925 ],
#        [0.46914953],
#        [0.4826815 ],
#        [0.48597533],
#        [0.4693111 ],
#        [0.48563135],
#        [0.4790277 ],
#        [0.49795258],
#        [0.4925807 ],
#        [0.49344778],
#        [0.48497778],
#        [0.50619054],
#        [0.48560232],
#        [0.49279332],
#        [0.4867705 ],
#        [0.47101355],
#        [0.45739925],
#        [0.4984839 ],
#        [0.478286  ],
#        [0.47848138],
#        [0.4466008 ],
#        [0.47837734],
#        [0.4915256 ],
#        [0.4876163 ],
#        [0.47153813],
#        [0.48255107],
#        [0.48599628],
#        [0.48688743],
#        [0.4841503 ],
#        [0.49440444],
#        [0.4881089 ],
#        [0.4772086 ],
#        [0.4983378 ],
#        [0.48036712],
#        [0.48847434],
#        [0.4745007 ],
#        [0.4993873 ],
#        [0.47155353],
#        [0.48179883],
#        [0.4953664 ],
#        [0.47040984],
#        [0.4878303 ],
#        [0.497089  ],
#        [0.50120485],
#        [0.48815274],
#        [0.49760926],
#        [0.50637734],
#        [0.48381126],
#        [0.47934452],
#        [0.5025442 ],
#        [0.49519756],
#        [0.48051322],
#        [0.47709313],
#        [0.48369572],
#        [0.48630545],
#        [0.48214388],
#        [0.4777568 ],
#        [0.50149393],
#        [0.47590446],
#        [0.5013151 ],
#        [0.4918902 ],
#        [0.49948615],
#        [0.5113047 ],
#        [0.5075417 ],
#        [0.49414897],
#        [0.4544295 ],
#        [0.4811877 ],
#        [0.48188442],
#        [0.48496878],
#        [0.47424003],
#        [0.49145928],
#        [0.49898684],
#        [0.47438532],
#        [0.49310106],
#        [0.48968655],
#        [0.4985863 ],
#        [0.507823  ],
#        [0.45926788],
#        [0.4702493 ],
#        [0.4800864 ],
#        [0.46934864],
#        [0.4867578 ],
#        [0.47960508],
#        [0.48001269],
#        [0.48266745],
#        [0.5150503 ],
#        [0.4788625 ],
#        [0.51618415],
#        [0.507511  ],
#        [0.48858762],
#        [0.48785552],
#        [0.47502643],
#        [0.5060319 ],
#        [0.48742622],
#        [0.48300636],
#        [0.47411242],
#        [0.49661046],
#        [0.47592145],
#        [0.47837213],
#        [0.50072765],
#        [0.46538144],
#        [0.47225577],
#        [0.46855038],
#        [0.48621964],
#        [0.47104383],
#        [0.5058558 ],
#        [0.5108984 ],
#        [0.48073426],
#        [0.4948271 ],
#        [0.50541615],
#        [0.4843784 ],
#        [0.5364169 ],
#        [0.51303834],
#        [0.48795384],
#        [0.48026645],
#        [0.5032841 ],
#        [0.5048594 ],
#        [0.4824082 ],
#        [0.48519832],
#        [0.4966757 ],
#        [0.49456024],
#        [0.5161386 ],
#        [0.5047886 ],
#        [0.48896226],
#        [0.49409392],
#        [0.5043767 ],
#        [0.49957377],
#        [0.48201528],
#        [0.49880818],
#        [0.49720815],
#        [0.5043228 ],
#        [0.48314148],
#        [0.4774016 ],
#        [0.49265307],
#        [0.48810157],
#        [0.49233425],
#        [0.48886955],
#        [0.46850193],
#        [0.5097433 ],
#        [0.48874307],
#        [0.48013797],
#        [0.5119638 ],
#        [0.4741521 ],
#        [0.48038137],
#        [0.46411604],
#        [0.4873092 ],
#        [0.4860262 ],
#        [0.4655825 ],
#        [0.49150586],
#        [0.48299322],
#        [0.49214765],
#        [0.4664304 ],
#        [0.4965937 ],
#        [0.4744509 ],
#        [0.49708283],
#        [0.49638855],
#        [0.49301738],
#        [0.48530936],
#        [0.48901358],
#        [0.5046032 ],
#        [0.48121363],
#        [0.49548832],
#        [0.50217634],
#        [0.4967545 ],
#        [0.47725374],
#        [0.5116521 ]], dtype=float32)
